# %%
#!uv add  langchain langchain_openai

# %%
#!uv add defusedxml

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import XMLOutputParser

# %%
import langchain_core.output_parsers as ot

print(dir(ot))
# Out:
# ['BaseCumulativeTransformOutputParser', 'BaseGenerationOutputParser', 'BaseLLMOutputParser', 'BaseOutputParser', 'BaseTransformOutputParser', 'CommaSeparatedListOutputParser', 'JsonOutputKeyToolsParser', 'JsonOutputParser', 'JsonOutputToolsParser', 'ListOutputParser', 'MarkdownListOutputParser', 'NumberedListOutputParser', 'PydanticOutputParser', 'PydanticToolsParser', 'SimpleJsonOutputParser', 'StrOutputParser', 'XMLOutputParser']

# %% [markdown]
# ### XMLOutputParser

# %%
xml_out = XMLOutputParser()
print(f"xml out : {dir(xml_out)}")

format_instructions = xml_out.get_format_instructions()
print()
print()
print(format_instructions)
# Out:
# xml out : ['InputType', 'OutputType', '__abstractmethods__', '__annotations__', '__class__', '__class_getitem__', '__class_vars__', '__copy__', '__deepcopy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__fields__', '__fields_set__', '__format__', '__ge__', '__get_pydantic_core_schema__', '__get_pydantic_json_schema__', '__getattr__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__or__', '__orig_bases__', '__parameters__', '__pretty__', '__private_attributes__', '__pydantic_complete__', '__pydantic_computed_fields__', '__pydantic_core_schema__', '__pydantic_custom_init__', '__pydantic_decorators__', '__pydantic_extra__', '__pydantic_extra_info__', '__pydantic_fields__', '__pydantic_fields_set__', '__pydantic_generic_metadata__', '__pydantic_init_subclass__', '__pydantic_on_complete__', '__pydantic_parent_namespace__', '__pydantic_post_init__', '__pydantic_private__', '__pydantic_root_model__', '__pydantic_serializer__', '__pydantic_setattr_handlers__', '__pydantic_validator__', '__reduce__', '__reduce_ex__', '__replace__', '__repr__', '__repr_args__', '__repr_name__', '__repr_recursion__', '__repr_str__', '__rich_repr__', '__ror__', '__setattr__', '__setstate__', '__signature__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abatch_with_config', '_abc_impl', '_acall_with_config', '_astream_events_v1_v2', '_astream_events_v3_unsupported', '_atransform', '_atransform_stream_with_config', '_batch_with_config', '_calculate_keys', '_call_with_config', '_copy_and_set_values', '_get_value', '_iter', '_root_to_dict', '_setattr_handler', '_transform', '_transform_stream_with_config', '_type', 'abatch', 'abatch_as_completed', 'ainvoke', 'aparse', 'aparse_result', 'as_tool', 'asdict', 'assign', 'astream', 'astream_events', 'astream_log', 'atransform', 'batch', 'batch_as_completed', 'bind', 'config_schema', 'config_specs', 'configurable_alternatives', 'configurable_fields', 'construct', 'copy', 'dict', 'encoding_matcher', 'from_orm', 'get_config_jsonschema', 'get_format_instructions', 'get_graph', 'get_input_jsonschema', 'get_input_schema', 'get_lc_namespace', 'get_name', 'get_output_jsonschema', 'get_output_schema', 'get_prompts', 'input_schema', 'invoke', 'is_lc_serializable', 'json', 'lc_attributes', 'lc_id', 'lc_secrets', 'map', 'model_computed_fields', 'model_config', 'model_construct', 'model_copy', 'model_dump', 'model_dump_json', 'model_extra', 'model_fields', 'model_fields_set', 'model_json_schema', 'model_parametrized_name', 'model_post_init', 'model_rebuild', 'model_validate', 'model_validate_json', 'model_validate_strings', 'name', 'output_schema', 'parse', 'parse_file', 'parse_obj', 'parse_raw', 'parse_result', 'parse_with_prompt', 'parser', 'pick', 'pipe', 'schema', 'schema_json', 'stream', 'stream_events', 'tags', 'to_json', 'to_json_not_implemented', 'transform', 'update_forward_refs', 'validate', 'with_alisteners', 'with_config', 'with_fallbacks', 'with_listeners', 'with_retry', 'with_types']
#
#
# The output should be formatted as a XML file.
# 1. Output should conform to the tags below.
# 2. If tags are not given, make them on your own.
# 3. Remember to always open and close all the tags.
#
# As an example, for the tags ["foo", "bar", "baz"]:
# 1. String "<foo>
#    <bar>
#       <baz></baz>
#    </bar>
# </foo>" is a well-formatted instance of the schema.
# 2. String "<foo>
#    <bar>
#    </foo>" is a badly-formatted instance.
# 3. String "<foo>
#    <tag>
#    </tag>
# </foo>" is a badly-formatted instance.
#
# Here are the output tags:
# ```
# None
# ```

# %%
template = "10개의 팀을 보여줘 {subject}.\n{format_instructions}"
prompt = PromptTemplate(
    input_variables=["subject"],
    template=template,
    partial_variables={"format_instructions": format_instructions},
)
print(prompt.format(subject="한국의 야구팀은"))
# Out:
# 10개의 팀을 보여줘 한국의 야구팀은.
# The output should be formatted as a XML file.
# 1. Output should conform to the tags below.
# 2. If tags are not given, make them on your own.
# 3. Remember to always open and close all the tags.
#
# As an example, for the tags ["foo", "bar", "baz"]:
# 1. String "<foo>
#    <bar>
#       <baz></baz>
#    </bar>
# </foo>" is a well-formatted instance of the schema.
# 2. String "<foo>
#    <bar>
#    </foo>" is a badly-formatted instance.
# 3. String "<foo>
#    <tag>
#    </tag>
# </foo>" is a badly-formatted instance.
#
# Here are the output tags:
# ```
# None
# ```

# %%
gpt = ChatOpenAI(model="gpt-4o-mini", temperature=0)
rst = gpt.invoke(prompt.format(subject="한국의 야구팀은"))
print(rst.content)
# Out:
# ```xml
# <baseball_teams>
#     <team>
#         <name>두산 베어스</name>
#         <city>서울</city>
#     </team>
#     <team>
#         <name>LG 트윈스</name>
#         <city>서울</city>
#     </team>
#     <team>
#         <name>키움 히어로즈</name>
#         <city>고양</city>
#     </team>
#     <team>
#         <name>삼성 라이온즈</name>
#         <city>대구</city>
#     </team>
#     <team>
#         <name>KIA 타이거즈</name>
#         <city>광주</city>
#     </team>
#     <team>
#         <name>롯데 자이언츠</name>
#         <city>부산</city>
#     </team>
#     <team>
#         <name>NC 다이노스</name>
#         <city>창원</city>
#     </team>
#     <team>
#         <name>SK 와이번스</name>
#         <city>인천</city>
#     </team>
#     <team>
#         <name>한화 이글스</name>
#         <city>대전</city>
#     </team>
#     <team>
#         <name>SSG 랜더스</name>
#         <city>인천</city>
#     </team>
# </baseball_teams>
# ```

# %%
xml_out.parse(rst.content)  # XML 파싱
# Out:
# {'baseball_teams': [{'team': [{'name': '두산 베어스'}, {'city': '서울'}]},
#   {'team': [{'name': 'LG 트윈스'}, {'city': '서울'}]},
#   {'team': [{'name': '키움 히어로즈'}, {'city': '고양'}]},
#   {'team': [{'name': '삼성 라이온즈'}, {'city': '대구'}]},
#   {'team': [{'name': 'KIA 타이거즈'}, {'city': '광주'}]},
#   {'team': [{'name': '롯데 자이언츠'}, {'city': '부산'}]},
#   {'team': [{'name': 'NC 다이노스'}, {'city': '창원'}]},
#   {'team': [{'name': 'SK 와이번스'}, {'city': '인천'}]},
#   {'team': [{'name': '한화 이글스'}, {'city': '대전'}]},
#   {'team': [{'name': 'SSG 랜더스'}, {'city': '인천'}]}]}

# %% [markdown]
# ### CommaSeparatedListOutputParser

# %%
from langchain_core.output_parsers import CommaSeparatedListOutputParser

# %%
output_parser = CommaSeparatedListOutputParser()
format_instructions = output_parser.get_format_instructions()
print(format_instructions)
# Out:
# Your response should be a list of comma separated values, eg: `foo, bar, baz` or `foo,bar,baz`

# %%
template = "List {number} {subject}. answer in Korean.\n{format_instructions}"
prompt = PromptTemplate(
    template=template,
    input_variables=["number", "subject"],
    partial_variables={"format_instructions": format_instructions},
)

print(prompt.format(number=4, subject="공포 영화"))
# Out:
# List 4 공포 영화. answer in Korean.
# Your response should be a list of comma separated values, eg: `foo, bar, baz` or `foo,bar,baz`

# %%
gpt = ChatOpenAI(model="gpt-4o-mini", temperature=0)
# rst = gpt.invoke( prompt.format( number=4, subject="공포 영화" )  )
rst = gpt.invoke(prompt.format(number=10, subject="한국의 야구팀"))
print(rst.content)
# Out:
# 두산 베어스, LG 트윈스, 키움 히어로즈, 삼성 라이온즈, KIA 타이거즈, 롯데 자이언츠, NC 다이노스, SSG 랜더스, 한화 이글스, kt wiz

# %%
gpt = ChatOpenAI(model="gpt-4o-mini", temperature=0)
# rst = gpt.invoke( prompt.format( number=4, subject="공포 영화" )  )
rst = gpt.invoke(prompt.format(number=4, subject="공포 영화"))
print(rst.content)
# Out:
# 컨저링, 미드소마, 유전, 악마를 보았다

# %% [markdown]
# ### JsonOutputParser

# %%
from langchain_core.output_parsers import JsonOutputParser

# %%
parser = JsonOutputParser()
format_instructions = parser.get_format_instructions()
print(format_instructions)
# Out:
# Return a JSON object.

# %%
template = "당신의 이름은 {name}이고, 나이는 {age}을 다음형식으로 출력:\n\n{format_instructions}"
prompt = PromptTemplate(
    input_variables=["name", "age"],
    template=template,
    partial_variables={"format_instructions": format_instructions},
)
print(prompt.format(name="홍길동", age=30))
# Out:
# 당신의 이름은 홍길동이고, 나이는 30을 다음형식으로 출력:
#
# Return a JSON object.

# %%
gpt = ChatOpenAI(model="gpt-4o-mini", temperature=0)
rst = gpt.invoke(prompt.format(name="홍길동", age=30))
print(rst.content)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 2
#       1 gpt = ChatOpenAI(model="gpt-4o-mini", temperature=0)
# ----> 2 rst = gpt.invoke(prompt.format(name="홍길동", age=30))
#       3 print(rst.content)
#       5 print(type(rst.content))
#
# File ~/Desktop/SK네트웍스/SKN_35/llm_workspace/.venv/lib/python3.12/site-packages/langchain_core/prompts/prompt.py:201, in PromptTemplate.format(self, **kwargs)
#     192 """Format the prompt with the inputs.
#     193
#     194 Args:
#    (...)
#     198     A formatted string.
#     199 """
#     200 kwargs = self._merge_partial_and_user_variables(**kwargs)
# --> 201 return DEFAULT_FORMATTER_MAPPING[self.template_format](self.template, **kwargs)
#
# File ~/.local/share/uv/python/cpython-3.12.13-macos-aarch64-none/lib/python3.12/string.py:190, in Formatter.format(self, format_string, *args, **kwargs)
#     189 def format(self, format_string, /, *args, **kwargs):
# --> 190     return self.vformat(format_string, args, kwargs)
#
# File ~/Desktop/SK네트웍스/SKN_35/llm_workspace/.venv/lib/python3.12/site-packages/langchain_core/utils/formatting.py:48, in StrictFormatter.vformat(self, format_string, args, kwargs)
#      43     msg = (
#      44         "No arguments should be provided, "
#      45         "everything should be passed as keyword arguments."
#      46     )
#      47     raise ValueError(msg)
# ---> 48 return super().vformat(format_string, args, kwargs)
#
# File ~/.local/share/uv/python/cpython-3.12.13-macos-aarch64-none/lib/python3.12/string.py:194, in Formatter.vformat(self, format_string, args, kwargs)
#     192 def vformat(self, format_string, args, kwargs):
#     193     used_args = set()
# --> 194     result, _ = self._vformat(format_string, args, kwargs, used_args, 2)
#     195     self.check_unused_args(used_args, args, kwargs)
#     196     return result
#
# File ~/.local/share/uv/python/cpython-3.12.13-macos-aarch64-none/lib/python3.12/string.py:234, in Formatter._vformat(self, format_string, args, kwargs, used_args, recursion_depth, auto_arg_index)
#     230     auto_arg_index = False
#     232 # given the field_name, find the object it references
#     233 #  and the argument it came from
# --> 234 obj, arg_used = self.get_field(field_name, args, kwargs)
#     235 used_args.add(arg_used)
#     237 # do any conversion on the resulting object
#
# File ~/.local/share/uv/python/cpython-3.12.13-macos-aarch64-none/lib/python3.12/string.py:299, in Formatter.get_field(self, field_name, args, kwargs)
#     296 def get_field(self, field_name, args, kwargs):
#     297     first, rest = _string.formatter_field_name_split(field_name)
# --> 299     obj = self.get_value(first, args, kwargs)
#     301     # loop through the rest of the field_name, doing
#     302     #  getattr or getitem as needed
#     303     for is_attr, i in rest:
#
# File ~/.local/share/uv/python/cpython-3.12.13-macos-aarch64-none/lib/python3.12/string.py:256, in Formatter.get_value(self, key, args, kwargs)
#     254     return args[key]
#     255 else:
# --> 256     return kwargs[key]
#
# KeyError: 'question'

# %%
parser.parse(rst.content)  # JSON 파싱
# Out:
# {'name': '홍길동', 'age': 30}

# %%
from pydantic import BaseModel, Field

# %%
class Country(BaseModel):
    continet: str = Field(description="사용자가 물어본 나라가 속한 대륙")
    population: int = Field(description="사용자가 물어본 나라의 인구")


parser = JsonOutputParser(pydantic_object=Country)
format_instructions = parser.get_format_instructions()
print(format_instructions)
# Out:
# STRICT OUTPUT FORMAT:
# - Return only the JSON value that conforms to the schema. Do not include any additional text, explanations, headings, or separators.
# - Do not wrap the JSON in Markdown or code fences (no ``` or ```json).
# - Do not prepend or append any text (e.g., do not write "Here is the JSON:").
# - The response must be a single top-level JSON value exactly as required by the schema (object/array/etc.), with no trailing commas or comments.
#
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]} the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema (shown in a code block for readability only — do not include any backticks or Markdown in your output):
# ```
# {"properties": {"continet": {"description": "사용자가 물어본 나라가 속한 대륙", "title": "Continet", "type": "string"}, "population": {"description": "사용자가 물어본 나라의 인구", "title": "Population", "type": "integer"}}, "required": ["continet", "population"]}
# ```

# %%
template = "answer the question.\n{question}\n\n{format_instructions}"
prompt = PromptTemplate(
    template=template,
    input_variables=["question"],
    partial_variables={"format_instructions": format_instructions},
)

print(prompt.format(question="아르헨티나는 어떤 나라야?"))
# Out:
# answer the question.
# 아르헨티나는 어떤 나라야?
#
# STRICT OUTPUT FORMAT:
# - Return only the JSON value that conforms to the schema. Do not include any additional text, explanations, headings, or separators.
# - Do not wrap the JSON in Markdown or code fences (no ``` or ```json).
# - Do not prepend or append any text (e.g., do not write "Here is the JSON:").
# - The response must be a single top-level JSON value exactly as required by the schema (object/array/etc.), with no trailing commas or comments.
#
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]} the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema (shown in a code block for readability only — do not include any backticks or Markdown in your output):
# ```
# {"properties": {"continet": {"description": "사용자가 물어본 나라가 속한 대륙", "title": "Continet", "type": "string"}, "population": {"description": "사용자가 물어본 나라의 인구", "title": "Population", "type": "integer"}}, "required": ["continet", "population"]}
# ```

# %%
gpt = ChatOpenAI(model="gpt-4o-mini", temperature=0)
rst = gpt.invoke(prompt.format(question="아르헨티나는 어떤 나라야?"))
print(rst.content)
# Out:
# {"continet":"남아메리카","population":45195777}
