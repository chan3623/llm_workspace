# %%
# basic.py
from common.common import get_chat

# 1. LangChain ChatOpenAI 객체 생성 (provider="openai" 전달)
gpt = get_chat(provider="openai", temperature=0)

# 2. LangChain 방식으로 호출
response = gpt.invoke("인공지능에 대해 설명해줘")

# 3. 결과 출력 (LangChain AIMessage 객체이므로 .content 사용 가능)
print(response.content)
# Out:
# 인공지능(AI, Artificial Intelligence)은 컴퓨터 시스템이나 기계가 인간의 지능을 모방하여 학습, 추론, 문제 해결, 이해, 언어 처리 등의 작업을 수행할 수 있도록 하는 기술입니다. 인공지능은 여러 분야에서 활용되며, 크게 두 가지로 나눌 수 있습니다.
#
# 1. **약한 인공지능(Weak AI)**: 특정 작업을 수행하도록 설계된 인공지능으로, 예를 들어 음성 인식, 이미지 인식, 추천 시스템 등이 이에 해당합니다. 약한 인공지능은 특정 문제를 해결하는 데 특화되어 있으며, 일반적인 지능을 갖추고 있지 않습니다.
#
# 2. **강한 인공지능(Strong AI)**: 인간과 유사한 수준의 지능을 갖춘 인공지능으로, 다양한 문제를 이해하고 해결할 수 있는 능력을 지니고 있습니다. 현재로서는 강한 인공지능은 이론적인 개념에 가까우며, 실제로 구현된 사례는 없습니다.
#
# 인공지능의 주요 기술로는 머신러닝(Machine Learning), 딥러닝(Deep Learning), 자연어 처리(Natural Language Processing), 컴퓨터 비전(Computer Vision) 등이 있습니다. 머신러닝은 데이터에서 패턴을 학습하여 예측이나 결정을 내리는 기술이며, 딥러닝은 인공신경망을 활용한 머신러닝의 한 분야입니다.
#
# 인공지능은 의료, 금융, 제조업, 자율주행차, 고객 서비스 등 다양한 분야에서 혁신을 가져오고 있으며, 앞으로도 그 발전 가능성이 무궁무진합니다. 그러나 윤리적 문제, 일자리 대체, 개인정보 보호 등의 이슈도 함께 논의되고 있습니다.

# %%
# basic.py
from common.common import get_chat

# 1. LangChain ChatOpenAI 객체 생성 (provider="openai" 전달)
gpt = get_chat(provider="gemini", temperature=0)

# 2. LangChain 방식으로 호출
response = gpt.invoke("인공지능에 대해 설명해줘")

# 3. 결과 출력 (LangChain AIMessage 객체이므로 .content 사용 가능)
print(response.content)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# [{'type': 'text', 'text': '**인공지능(AI, Artificial Intelligence)**은 쉽게 말해 **"기계나 컴퓨터가 인간처럼 생각하고, 학습하고, 판단할 수 있도록 만드는 기술"**입니다. \n\n과거의 컴퓨터는 인간이 입력한 명령어대로만 작동했지만, 인공지능은 스스로 데이터를 학습하여 새로운 상황에 대처할 수 있습니다.\n\n이해하기 쉽게 핵심 개념, 작동 원리, 종류, 그리고 우리 삶에 미치는 영향으로 나누어 설명해 드릴게요.\n\n---\n\n### 1. 인공지능의 핵심 개념 (AI > 머신러닝 > 딥러닝)\n인공지능을 이야기할 때 가장 많이 혼용되는 세 가지 개념의 관계는 다음과 같습니다.\n\n*   **인공지능 (AI):** 인간의 지능을 모방하는 모든 기술을 포함하는 가장 넓은 개념입니다.\n*   **머신러닝 (Machine Learning, 기계학습):** AI의 한 분야로, 컴퓨터에 수많은 데이터를 주고 **스스로 규칙을 찾아 학습**하게 만드는 기술입니다. (예: 개와 고양이 사진 수만 장을 보여주면, 컴퓨터가 스스로 개와 고양이의 특징을 구별하게 됨)\n*   **딥러닝 (Deep Learning):** 머신러닝의 일종으로, 인간의 **뇌 신경망(Neural Network)**을 모방한 기술입니다. 엄청나게 복잡하고 많은 데이터 속에서 스스로 학습하며, 현재 AI 열풍(ChatGPT, 자율주행 등)을 이끄는 핵심 기술입니다.\n\n---\n\n### 2. 인공지능의 종류\nAI는 능력의 범위에 따라 크게 두 가지로 나뉩니다.\n\n*   **약인공지능 (Narrow AI):** \n    *   **특정 한 가지 분야**만 잘하는 AI입니다. \n    *   예: 바둑만 잘 두는 \'알파고\', 번역만 잘하는 \'파파고\', 스마트폰 비서(시리, 빅스비), 추천 알고리즘(유튜브, 넷플릭스).\n    *   *현재 인류가 개발한 모든 AI는 약인공지능에 속합니다.*\n*   **강인공지능 (General AI / AGI):**\n    *   인간처럼 **다양한 분야에서 스스로 생각하고 문제를 해결**할 수 있는 AI입니다.\n    *   영화 속 \'아이언맨\'의 자비스나 \'터미네이터\' 같은 존재로, 현재 전 세계 테크 기업들이 개발하기 위해 치열하게 경쟁하고 있는 단계입니다.\n\n---\n\n### 3. 우리 생활 속의 인공지능 사례\n이미 AI는 우리 삶 깊숙이 들어와 있습니다.\n\n*   **생성형 AI (Generative AI):** 질문을 하면 답변을 해주는 **ChatGPT**, 그림을 그려주는 **미드저니(Midjourney)**처럼 새로운 콘텐츠를 창작하는 AI입니다.\n*   **자율주행:** 테슬라나 웨이모처럼 카메라와 센서로 도로 상황을 인식하고 스스로 운전하는 자동차입니다.\n*   **의료 분야:** 의사보다 더 정확하게 엑스레이나 MRI 사진을 분석해 암을 진단합니다.\n*   **금융 분야:** 주식 시장을 예측하거나, 신용카드 도난 및 이상 거래를 실시간으로 감지합니다.\n\n---\n\n### 4. 인공지능의 장점과 우려되는 점\n\n**👍 장점:**\n*   **효율성 극대화:** 인간이 하기 힘들거나 반복적인 업무를 빠르고 정확하게 처리합니다.\n*   **새로운 가능성:** 신약 개발 기간을 획기적으로 단축하거나, 기후 변화 해결책을 제시하는 등 인류의 난제를 해결하는 데 기여합니다.\n*   **편의성:** 일상적인 비서 역할부터 맞춤형 교육, 엔터테인먼트까지 삶의 질을 높여줍니다.\n\n**👎 우려되는 점 (한계와 부작용):**\n*   **일자리 변화:** 단순 반복 업무나 일부 전문직의 일자리가 AI로 대체될 수 있습니다.\n*   **편향성과 오류:** AI가 학습한 데이터에 편견이 섞여 있다면, AI 역시 차별적이거나 잘못된 판단(환각 현상, Hallucination)을 내릴 수 있습니다.\n*   **윤리적 문제:** 딥페이크(가짜 영상/목소리)를 이용한 범죄나 개인정보 침해 문제가 발생할 수 있습니다.\n\n---\n\n### 요약하자면\n인공지능은 **"인간의 능력을 확장해 주는 가장 강력한 도구"**입니다. 불과 몇 년 전만 해도 상상 속의 기술이었던 AI는 이제 스마트폰처럼 우리 삶의 필수적인 도구가 되었으며, 앞으로 인류의 미래를 가장 크게 바꿀 기술임이 틀림없습니다.', 'extras': {'signature': '...'}}]
