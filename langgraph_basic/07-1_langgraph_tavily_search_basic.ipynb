# %% [markdown]
# # 07-1. Tavily 검색 노드 만들기
#
# 이 실습은 LangGraph에서 외부 검색 도구를 하나의 노드로 연결하는 가장 단순한 예제이다.
#
# ## 학습 목표
#
# 1. Tavily 검색 도구를 LangGraph 노드로 만든다.
# 2. `State`에 검색어와 검색 결과를 저장한다.
# 3. `START → 검색 → END` 구조의 가장 단순한 그래프를 구성한다.
# 4. `invoke()`와 `stream()`으로 실행 결과를 확인한다.
#
# ## 전체 흐름
#
# ```text
# START
#   ↓
# 검색
#   ↓
# END
# ```
#
# 이 단계에서는 LLM을 사용하지 않는다. 먼저 외부 검색 API가 LangGraph 노드 안에서 어떻게 실행되는지만 확인한다.

# %% [markdown]
# ## 0. 설치 패키지
#
# 이 실습은 LangGraph, OpenAI 모델, Tavily 검색 도구를 사용한다.
# 처음 실행하는 환경에서는 아래 명령으로 필요한 패키지를 설치한다.
# Tavily : 실시간 웹 검색 API, 월 1000 크래딧 무료 사용 가능하다.
#
# ```bash
# uv add langgraph langchain-openai langchain-tavily langchain-core python-dotenv grandalf
# ```
#
# `.env` 파일에는 다음 값을 설정한다.
#
# ```text
# OPENAI_API_KEY=발급받은_OpenAI_API_Key
# TAVILY_API_KEY=발급받은_Tavily_API_Key
# ```

# %%
import sys
from pathlib import Path

# 현재 폴더의 상위 폴더를 Python import 경로에 추가
sys.path.append(str(Path.cwd().parent))
# 공통 환경 설정
# - .env 파일에서 API Key를 읽는다.
# - API Key가 없으면 실습 초반에 명확한 오류를 발생시킨다.
from const.const import API_KEY, MODEL, TAVILY_API_KEY


OPENAI_API_KEY = API_KEY
TAVILY_API_KEY = TAVILY_API_KEY

if not OPENAI_API_KEY:
    raise ValueError("OPENAI_API_KEY가 설정되어 있지 않다. ../.env 파일을 확인한다.")

if not TAVILY_API_KEY:
    raise ValueError("TAVILY_API_KEY가 설정되어 있지 않다. ../.env 파일을 확인한다.")

print("환경 변수 로드 완료")
# Out:
# 환경 변수 로드 완료

# %%
# LangGraph 기본 구성 요소와 Tavily 검색 도구를 불러온다.
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START, END
from langchain_tavily import TavilySearch
from IPython.display import Image, display

# TavilySearch는 외부 웹 검색을 수행하는 도구이다.
# max_results는 검색 결과 개수를 의미한다.
tavily_tool = TavilySearch(max_results=5)

# %%
def normalize_tavily_results(raw_result) -> list[dict]:
    """Tavily 검색 결과를 list[dict] 형태로 정리한다.

    TavilySearch의 반환값은 보통 {"results": [...]} 형태이다.
    실습에서는 이후 노드가 사용하기 쉽도록 검색 결과 리스트만 추출한다.
    """
    if isinstance(raw_result, dict):
        return raw_result.get("results", [])

    if isinstance(raw_result, list):
        return raw_result

    return []


def format_search_results(results: list[dict]) -> str:
    """검색 결과를 LLM 프롬프트에 넣기 쉬운 문자열로 변환한다."""
    if not results:
        return "검색 결과가 없다."

    lines = []
    for idx, item in enumerate(results, start=1):
        title = item.get("title", "제목 없음")
        url = item.get("url", "URL 없음")
        content = item.get("content", "내용 없음")

        lines.append(f"[{idx}] {title}\nURL: {url}\n내용: {content}")

    return "\n\n".join(lines)


def show_graph(app):
    """그래프 구조를 시각화한다.

    Mermaid 이미지 생성이 실패하면 ASCII 그래프로 대체한다.
    """
    try:
        display(Image(app.get_graph().draw_mermaid_png()))
    except Exception as e:
        print(f"Mermaid 이미지 생성 실패: {e}")
        print(app.get_graph().draw_ascii())

# %% [markdown]
# ## 1. State 정의
#
# `State`는 그래프 실행 중 유지되는 공유 상태 객체이다.
#
# 이 단계에서는 세 가지 정보만 사용한다.
#
# | 필드             | 의미                        |
# | ---------------- | --------------------------- |
# | `topic`          | 사용자가 알고 싶은 주제     |
# | `search_query`   | 실제 Tavily에 전달할 검색어 |
# | `search_results` | Tavily 검색 결과            |

# %%
class SearchState(TypedDict):
    # 사용자가 입력한 원래 주제이다.
    topic: str

    # 실제 Tavily 검색에 사용할 검색어이다.
    search_query: str

    # Tavily에서 받은 검색 결과 목록이다.
    search_results: list[dict]

# %% [markdown]
# ## 2. 검색 노드 정의
#
# 노드는 State를 입력으로 받고, 변경할 값만 딕셔너리로 반환한다.
#
# 이 노드는 다음 작업을 수행한다.
#
# 1. `topic`의 값을 검색어로 사용한다.
# 2. Tavily 검색을 실행한다.
# 3. 검색 결과를 `search_results`에 저장한다.

# %%
def search_node(state: SearchState) -> dict:
    """Tavily 검색을 수행하는 노드이다."""

    # topic을 실제 검색어로 사용한다.
    query = state["topic"]
    print(f"검색어: {query}")

    # Tavily 검색 도구를 실행한다.
    raw_result = tavily_tool.invoke({"query": query})

    # Tavily 결과에서 results 리스트만 추출한다.
    results = normalize_tavily_results(raw_result)
    print(f"검색 결과 수: {len(results)}")

    # 노드는 변경할 State 값만 반환한다.
    return {
        "search_query": query,
        "search_results": results,
    }

# %% [markdown]
# ## 3. 그래프 구성
#
# 가장 단순한 그래프는 하나의 노드만 가진다.
#
# ```text
# START → 검색 → END
# ```

# %%
# StateGraph는 SearchState 구조를 기준으로 그래프를 만든다.
builder = StateGraph(SearchState)

# 검색 노드를 그래프에 등록한다.
builder.add_node("검색", search_node)

# START에서 검색 노드로 이동한다.
builder.add_edge(START, "검색")

# 검색 노드가 끝나면 그래프를 종료한다.
builder.add_edge("검색", END)

# compile()을 해야 실행 가능한 그래프가 된다.
app = builder.compile()

show_graph(app)

# %% [markdown]
# ## 4. 그래프 실행
#
# `invoke()`는 그래프를 처음부터 끝까지 실행하고 최종 State를 반환한다.

# %%
result = app.invoke(
    {
        "topic": "인공지능 최신 동향",
        "search_query": "",
        "search_results": [],
    }
)

print("최종 검색어:", result["search_query"])
print("검색 결과 수:", len(result["search_results"]))

# 검색 결과 제목만 간단히 확인한다.
for idx, item in enumerate(result["search_results"], start=1):
    print(f"{idx}. {item.get('title', '제목 없음')}")
# Out:
# 검색어: 인공지능 최신 동향
# 검색 결과 수: 5
# 최종 검색어: 인공지능 최신 동향
# 검색 결과 수: 5
# 1. 인공지능 분야 산업·기술 동향 및 이슈
# 2. AI 트렌드 어디로 가고 있을까?｜2026 산업 동향·핵심 기술 정리 - 윈스펙 커뮤니티
# 3. 주요 인공 지능 트렌드 | IBM
# 4. 2026년에 주목해야 할 10가지 인공지능 트렌드
# 5. AI 최신 트렌드를 한눈에 - 국내·외 추천 AI 허브 사이트 총정리

# %% [markdown]
# ## 5. stream으로 단계별 실행 확인
#
# `stream_mode="updates"`는 각 노드가 반환한 업데이트 값만 보여준다.
# 검색 노드가 어떤 값을 State에 추가하는지 확인할 수 있다.

# %%
for event in app.stream(
    {
        "topic": "2026년 생성형 AI 교육 트렌드, url 오픈 가능한 자료만 추출하기",
        "search_query": "",
        "search_results": [],
    },
    stream_mode="updates",
):
    # print(event)
    # for update_data in event.values():
    #     print(update_data)
    for update_data in event.values():
        if "search_results" in update_data:
            for i, item in enumerate(update_data["search_results"], start=1):
                print(f"\n[{i}] {item.get('title')}")
                print(item.get("url"))
                print(item.get("content"))
                print("-" * 10)
# Out:
# 검색어: 2026년 생성형 AI 교육 트렌드, url 오픈 가능한 자료만 추출하기
# 검색 결과 수: 5
#
# [1] [무료] HRD를 위한 <2026년 생성형 AI 교육 트렌드> - 블로그
# https://codeit.kr/teams/blog/70952
# 뉴스룸
#
# # [무료] HRD를 위한 <2026년 생성형 AI 교육 트렌드>
#
# 2026년 생성형 AI 기업교육 트렌드를 한눈에! HRD 담당자를 위한 무료 웨비나에서 교육 성공 사례, 산업별 Best Practice, 업무자동화 시연까지 확인하세요.
#
# 코드잇 기업교육's avatar
#
# 코드잇 기업교육
#
# Sep 19, 2025
#
# ![[무료] HRD를 위한 <2026년 생성형 AI 교육 트렌드>](
#
# Contents
#
# 1. 행사 일정2. 웨비나 참여 혜택3. 연사 소개4. 추천 대상5. 핵심 인사이트6. 프로그램 구성7. 자주 묻는 질문 (FAQ)
#
# 2025년은 생성형 AI가 기업교육의 판도를 크게 바꾼 해였습니다. 기술은 빠르게 발전했고, GPT-5와 AI Agent 같은 새로운 개념들이 연이어 등장했습니다. 하지만 정작 교육 담당자들에게 중요한 건 최신 기술을 빠르게 파악하는 게 아니라, 이걸 어떻게 사내 교육에 효과적으로 녹여낼 수 있을까 하는 문제였습니다. [...] 2026년, 생성형 AI 교육의 방향성 (사내 챗봇 확산, AI Agent, RPA와 생성형 AI 결합)
#
# PART 2
#
#  2025년 산업군 별 생성형 AI 활용 사례 및 교육 Best Practice 사례
#
#  생성형 AI를 활용한 업무자동화 시연 (\ 업무자동화 시연 내용은 변경될 수 있습니다.)
#
# + 유저 CS 자동 응대 시스템 구축
# + 비전공자를 위한 SQL 도출 시스템 구축
#
# Q&A
#
#  사전 질문에 대한 Q&A
#
# ### 7. 자주 묻는 질문 (FAQ)
#
# Q. 참가비가 있나요?
#
# A. 무료로 진행됩니다.
#
# Q. 다시보기 제공되나요?
#
# A. 다시보기 서비스를 제공합니다. 단, 보안 문제로 교육 사례 발표는 라이브에서만 확인 가능합니다.
#
# 다가올 2026년, 생성형 AI 교육의 흐름을 누구보다 먼저 준비해보세요.
#
# 이번 웨비나에서 얻은 인사이트가 내년 교육 전략의 든든한 출발점이 될 것입니다.
#
# 하단 버튼을 눌러 30초 만에 신청하세요✨
#
# Share article [...] ### 4. 추천 대상
#
# 👤
#
#  2026년 생성형 AI 교육을 고민하고 있는 교육 담당자
#
#  다른 기업의 생성형 AI 교육 성공 사례가 궁금한 담당자
#
#  AI 기반 DX·AX 교육을 준비 중이거나, 전사 확산 전략이 필요한 교육 담당자
#
# ### 5. 핵심 인사이트
#
# 1. 생성형 AI 교육 성공 사례
#
# 다양한 산업에서 성공적으로 진행한 생성형 AI 교육 사례를 알아갈 수 있습니다.
#
# 2. 2026년 기업교육 방향성 전망
#
# AI 최신 기술이 매달 업데이트 되고 있는 이 때, 우리는 어떻게 2026년 생성형 AI 교육 방향을 준비해야할 지 알아갈 수 있습니다.
#
# 3. 생성형 AI 기반 업무자동화 시연
#
# 우리 구성원이 실제 업무에서 생성형 AI를 활용해 어떻게 업무자동화를 할 수 있을지 알아갈 수 있습니다.
#
# ### 6. 프로그램 구성
#
# PART 1
#
#  2025년 한 판으로 정리하는 생성형 AI 교육 현황
# ----------
#
# [2] AI 리드 생성 완전 정복: 2026년을 위한 궁극의 가이드
# https://thunderbit.com/ko/blog/ai-lead-generation
# 브라우저에서 Thunderbit 아이콘을 클릭합니다.
#  데이터 소스로 “Current Page”를 선택합니다(또는 여러 URL을 입력해 일괄 스크래핑할 수도 있습니다).
#  페이지에 페이지네이션이나 무한 스크롤이 있으면 Thunderbit이 자동 감지하도록 두거나 수동으로 설정합니다.
#
# ### 4. One Click Extract 실행하기
#
#  One Click Extract를 클릭합니다. Thunderbit의 AI가 페이지를 스캔하고 구조를 파악한 뒤, 어떤 필드를 추출할지 스스로 결정합니다(예: 이름, 회사, 이메일). 미리 정의할 것이 없습니다.
#  페이지 전체는 물론, 활성화했다면 페이지네이션과 하위 페이지까지 함께 추출됩니다.
#
# ### 5. 필요하면 컬럼 조정하기 [...] 컬럼을 수정, 추가, 삭제하고 각 필드의 데이터 유형(Text, Number, Email 등)을 설정합니다.
#  “@” 앞의 직책만 추출해라”, “회사 설명을 영어로 번역해라” 같은 고급 추출용 AI 프롬프트를 추가한 뒤 다시 실행합니다.
#  결과를 표로 미리 확인합니다. 이상한 부분이 있으면 컬럼이나 프롬프트를 조정하고 다시 실행합니다.
#
# ### 6. 하위 페이지 스크래핑하기(선택 사항)
#
#  URL이 들어 있는 컬럼(예: 프로필 링크)이 있다면 Subpage Scraping을 실행합니다.
#  각 하위 페이지에서 추가로 추출할 필드(예: 회사 소개, LinkedIn URL)를 지정합니다.
#  Thunderbit이 각 링크를 방문해 정보를 추출하고, 메인 테이블에 추가합니다.
#
# ### 7. 데이터 내보내기
#
#  한 번의 클릭으로 Excel/CSV, Google Sheets, Airtable, Notion으로 내보낼 수 있습니다.
#  무료 플랜에서도 내보내기는 모두 무료이며 무제한입니다. [...] 원클릭 추출: Thunderbit의 AI가 페이지를 읽고 구조를 파악한 뒤, 이름, 회사, 이메일, 직책, 업종 같은 필드를 스스로 추출합니다. 처음부터 필드를 정의할 필요가 없습니다. 원하는 게 다르면 나중에 수정하거나 추가하면 됩니다.
#  Scheduled Scraper: 이벤트 페이지, 채용 공고, 기업 디렉터리 같은 소스에서 반복 수집 작업을 예약해 둘 수 있습니다. Thunderbit이 리드 리스트를 자동으로 최신 상태로 유지합니다.
#  하위 페이지 및 페이지네이션 스크래핑: 여러 페이지를 넘기거나, 세부 정보를 보려면 하위 페이지까지 들어가야 하나요? Thunderbit이 그것도 처리합니다.
#  다국어 지원: 50개 이상의 언어로 된 웹사이트에서 데이터를 추출하고 번역할 수 있어, 글로벌 팀에 적합합니다.
#  무료 데이터 내보내기: Excel, Google Sheets, Airtable, Notion으로 리드를 추가 비용 없이 내보낼 수 있습니다.
# ----------
#
# [3] Revealed! Top 10 AI Trends for 2026 - YouTube
# https://www.youtube.com/watch?v=7vjPpSe2TjM
# 있다가 일본에 있는 회사들이 디지털 카메라를 내니까 뒤늦게 내서 그거에 대해서 제대로 적응하지 못했던 그 똑같은 행동을 처음에 구글이 합니다. 그래서 갑자기 오픈 A가 등장하고 나서 급하게 낸게 우리가 알고 있었던 바드라고 하는 모델이죠. 근데 바드가 제대로 된 답변을 안 하면서 주가가 폭락하는 일이 발생했습니다. 그다음에 구글이 모든 역량을 생성형 AI에 집중합니다. 그리고 나온게 바로 최근에 나오는 재미나이 2.5부터 엄청난 성능을 보여주기 시작합니다. 구글이 제대로 자기들의 영향을 모으기 시작했죠. 그중에서 가장 놀라웠던 건 바로 나노바나라는 녀석의 열풍입니다. 그전에 우리가 AI가 그림을 그리면 재밌게 그려지는데 첫 번째 그림 이미지를 두 번째로 바꾼다라고 하면 첫 번째 이미지가 유지가 안 됐거든요. 근데 그거를 해결하기 시작한게 구글에 나노바나라는 것부터죠. 예를 들면 여기 있는 것처럼 그냥 우리가 유명한 유명 인사랑 그리고 바나나키 이미지 넣고 실제로이 두 개를 이미지를 [...] 하는 사이트에서 종합 벤치마크를 하고 있는이 점수의 그래프라고 보시면 될 것 같습니다. 요게 보면 되게 많은 어떤 그 회사들이 있죠.이 회사들이 다 언어 모델 하고 있는 회사들의 어떠한 지금의 성능을 보여주는 종합 지표라고 보시면 돼요. 맨 위에가 역시 오픈 AI 그죠? 오픈 AI인데이 재밌는 거는이 그래프의 전체적인 기울기를 보시면 두 가지 포인트에서 흥미로운게 있습니다. 하나는요. 오픈 AI가 채치 초기에는 다른 모델에 비해서 압도적인 격차를 보여 줄 때가 많았다는 거예요. 아주 틈이 많이 벌어지고 있는 형태들 보이시죠? 그런데 갈수록 어떻게 됩니까? 오히려 오픈 AI가 뭔가 나면 다른 데들이 금방금방 따라잡기 시작을 해요. 그래서 최근에 보면은 중국에 있는 모델들이나 그죠? 아니면은 뭐 XAI 같은 모델들이 금방금방 생성형 AI 채치T가 업그레이드되면 또 따라가는 형태를 보여줍니다. 두 번째로는요.이 전체적인 기울기를 보면 처음에는 되게이 기울기가 어떤 변곡점에서 툭툭 빨리 [...] AI라는 키워드입니다. 보통 피지컬 AI 얘기할 때 제일 많이 하는게 젠슨왕이 발표테 쓰는 장표인데요. 처음에 우리가 AI를 가지고 많이 했던게인지 펄셉션 AI잖아요. 그거를 비율을 하면 이런 거죠.이 AI한테 우리가 햄버거 이미지를 주면서 이거 뭐야라고 물어보면 AI가 어 이거 햄버거입니다. 치즈버거네요라고 인지하는 거. 그게 우리가 전통적으로 알고 있었던 AI죠. 자 그다음에 생성형 AI는 뭐예요? 어 그러면 실제로이 햄버거를 맛있게 먹고 있는 사람을 그려 봐. 그러면은 아주 맛있게 먹고 있는 걸 그리죠. 자, 이게 생성형 AI라고 하면 제가 그걸 보고 배가 고파서 아, 나 배고프다라고 얘기했더니 AI가 어, 그럼 제가 주문을 해 드릴까요라고 하면서 웹사이트를 켜고 제가 지금 보고 있는 치즈버거를 주문해 주는 거. 이게 에이전트 AI라고 할 수 있어요. 그런데 그 에이전트 AI 되면 피지컬 AI는 뭐냐? 사람이 배달을 하러 갔죠. 배달을 하러 갔더니 햄버거 가기가 특이하게
# ----------
#
# [4] 2026 AI 교육 트렌드 5가지는 이겁니다. 프롬프트? 아닙니다.
# https://contents.premium.naver.com/ajeong/aijeong/contents/260428155111478rs
# 좋은 AI 활용은 많이 쓰는걸 넘어, 내 상황에 맞게 설계하는 것입니다. AI를 업무와 사업에 붙여 실제 성과로 연결하는 방법을 다룹니다.
#
# ​
#
#  공식홈페이지
#  유튜브
#  네이버 블로그
#  인스타그램
#  스레드
#
# ​
#
# ​
#
# ​
#
# ​
#
# ​
#
# 해당 콘텐츠는 프리미엄 구독자 공개(유료) 콘텐츠로 무단 캡쳐 및 불법 공유시 법적 제재를 받을 수 있습니다.
#
# 본 콘텐츠는 무료로 제공중입니다.
# 콘텐츠가 마음에 드셨나요?
#
# 에이정 구독으로 더 많은 콘텐츠를 만나보세요!
#
# 프리미엄 구독
#
# 4,900 원/월
#
#
#
#    에이정
#
#   안녕하세요. 에이정입니다.
#
#  #2026AI트렌드
#  #AI교육트렌드
#  #2026AI교육트렌드
#  #AI교육
#  #에이전트설계
#
# 좋아요
#
#  댓글
#
# 공유하기
#
# 에이정
#
# 이 채널의 콘텐츠가 마음에 드셨나요?
#  채널을 구독하고 창작자의 콘텐츠를 응원해 주세요!
#
# IT테크/과학
#
# ### 무료 콘텐츠 모아보기
#
#
#
#   기업 91%가 AI 교육 예산을 늘리는 5가지 이유 [...] 최신 자료를 겹쳐보면 교육 내용 자체가 그렇게 이동할 수밖에 없는 이유가 분명하게 보입니다.
#
# > 첫 번째 트렌드, 공통 프롬프트 강의에서 역할별 적용 교육으로 옮겨갑니다
#
# WEF의 Future of Jobs Report 2025를 보면 AI와 빅데이터는 향후 5년간 가장 빠르게 중요도가 커질 기술 역량으로 제시됩니다. 동시에 기술 역량만 커지는 게 아닙니다. 분석적 사고, 창의적 사고, 회복탄력성, 호기심과 평생학습도 함께 중요해지고 있죠.
#
# ​
#
# 이게 의미하는건 뭘까요? AI 교육이 단순 사용법 전달로 끝날 수 없다는 것이죠. 같은 툴을 써도 마케팅은 조사와 초안 작성에 붙이고, 영업은 제안서와 고객 대응에 붙이며, 인사는 채용과 교육 운영에 다르게 붙여야 합니다. 역할이 다르면 필요한 판단도 달라집니다.
#
# ​ [...] 본문 바로가기
#
# # Premium Contents
#
# 이전 페이지
#
# ## 에이정
#
# 검색
#
# 2026 AI 교육 트렌드 5가지는 이겁니다. 프롬프트? 아닙니다.
#
# 2026.04.29. 오후 2:00
#
#
#
# by  에이정
#
# 댓글
#
# SNS 보내기
#
# 가
#
# ​
#
# ​
#
# > 한 줄 결론
#
# 2026년 AI 교육 트렌드 변화는 프롬프트만 가르쳐서는 현업 적용이 남지 않기 때문에, 교육의 무게중심이 역할별 적용, 가이드라인, 측정, 그리고 에이전트 설계 감각 쪽으로 옮겨가고 있다는 데 있습니다.
#
# > 저는 요즘 교육 문의에서 질문이 바뀌었다고 느낍니다
#
# 불과 얼마 전까지만 해도 교육 문의의 중심에는 이런 질문이 많았습니다. "어떤 프롬프트를 알려주면 되나요", "ChatGPT 기능 소개 위주로 가면 되나요", "직원들이 일단 써보게 만드는 게 먼저 아닌가요" 같은 질문이었죠.
#
# ​
# ----------
#
# [5] 2026년 최고의 AI교육 프로그램 - AI CRAFT
# https://www.youtube.com/watch?v=q3cw7H4VT1U
# # 2026년 최고의 AI교육 프로그램 - AI CRAFT
# ## Channel: Ai Learn
# 707 subscribers
# 3 likes
#
# ### Description
# 435 views
# Posted: 2026-02-03
# 교사가 별도 코딩/개발 지식 없이,
# 학생과 함께 프롬프트만으로 수업용 AI 챗봇을 만들고,
# 교과 자료(PDF)를 업로드 해, 자료 기반(RAG) 질의 응답까지 체험하는
# 수업용 생성형 AI 학습지원 플랫폼
#
# ※별도 외부 강사 없이 교사가 직접 진행할 수 있는 수업 구조
# ※학습지원 소프트웨어 필수기준 충족한 안심 플랫폼
#
# #생성형 AI 수업
# #AI 챗봇 만들기 수업
# #자유학기제 AI 프로그램
# #창체 · 동아리 AI 활동
# #교과 연계 AI 수업자료
# #학생 개인정보 없는 AI 수업
# #학습지원 소프트웨어 필수기준 충족 [...] ### Transcript
# [0:02] AI 수업 준비가 복잡하면 시작이 어렵습니다. 그래서 AI 크라프트이 화면 하나로 모든 수업 준비가
# [0:10] 끝납니다. 이름을 정하고 [음악] 말투를 고르고 PDF를 업로드만 하면 끝입니다.
# [0:20] 마지막으로 버튼 한 번만 누르면 채봇이 완성됩니다.
# [0:25] 채포에 질문을 하면 PDF 기반으로 답을 합니다.
# [0:31] AI 크래프트는 모든 과목에 적용이 가능하고 각 과목별로 수업용 PDF만 준비하면 끝입니다.
# [0:39] 교과 외한 활용 영역별로도 수업 연계성이 높습니다.
# [0:46] 교사 부담없는 AI 수업 지금 바로 신청하세요. AI크래프트. M.
# ----------

# %% [markdown]
# ## 정리
#
# 이 단계에서 확인한 내용은 다음과 같다.
#
# 1. 외부 API 호출도 LangGraph 노드 안에서 실행할 수 있다.
# 2. 노드는 전체 State가 아니라 변경할 값만 반환한다.
# 3. `START → 검색 → END` 구조는 가장 단순한 LangGraph 파이프라인이다.
# 4. 다음 단계에서는 검색 결과를 LLM으로 정리하는 노드를 추가한다.

# %% [markdown]
# ---
#
# ## 핵심 정리
#
# ```python
# # 1. Tavily Search 도구 초기화
# from langchain_tavily import TavilySearch
#
# tavily_tool = TavilySearch(
#     max_results=5,
#     topic="news",
#     search_depth="advanced",
#     time_range="month",
# )
#
# raw_result = tavily_tool.invoke({"query": "검색어"})
# results = raw_result["results"]
#
# # 2. LangGraph State 정의
# from typing_extensions import TypedDict
#
# class SearchState(TypedDict):
#     topic: str
#     search_query: str
#     search_results: list[dict]
#
# # 3. 검색 노드 정의
# def search_node(state: SearchState) -> dict:
#     query = state["search_query"] or state["topic"]
#     raw_result = tavily_tool.invoke({"query": query})
#     results = raw_result["results"]
#
#     return {
#         "search_query": query,
#         "search_results": results,
#     }
#
# # 4. 그래프 구성
# from langgraph.graph import StateGraph, START, END
#
# builder = StateGraph(SearchState)
# builder.add_node("검색", search_node)
# builder.add_edge(START, "검색")
# builder.add_edge("검색", END)
#
# app = builder.compile()
# ```
#
# | 구성 요소            | 역할                                                        |
# | -------------------- | ----------------------------------------------------------- |
# | `SearchState`        | 그래프 실행 중 유지할 상태 구조를 정의한다.                 |
# | `검색` 노드          | Tavily Search API로 최신 뉴스 검색을 수행한다.              |
# | `search_query`       | 실제 검색에 사용한 검색어를 저장한다.                       |
# | `search_results`     | Tavily에서 반환한 검색 결과 목록을 저장한다.                |
# | `START → 검색 → END` | 하나의 검색 노드만 실행하는 가장 단순한 LangGraph 흐름이다. |
#
# 이 실습은 LangGraph에서 **외부 API 호출을 하나의 노드로 구성하고, 실행 결과를 State에 저장하는 기본 예제**이다.
