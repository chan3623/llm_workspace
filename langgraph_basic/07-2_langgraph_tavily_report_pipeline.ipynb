# %% [markdown]
# # 07-2. 검색 결과를 뉴스 리포트로 정리하기
#
# 이 실습은 1단계 검색 그래프에 LLM 리포트 작성 노드를 추가하는 예제이다.
#
# ## 학습 목표
#
# 1. 검색 노드와 리포트 작성 노드를 순차적으로 연결한다.
# 2. Tavily 검색 결과를 LLM 프롬프트에 넣기 좋은 문자열로 변환한다.
# 3. LLM이 검색 결과를 바탕으로 뉴스 리포트를 생성하도록 구성한다.
# 4. `START → 검색 → 리포트작성 → END` 흐름을 이해한다.
#
# ## 전체 흐름
#
# ```text
# START
#   ↓
# 검색
#   ↓
# 리포트작성
#   ↓
# END
# ```

# %% [markdown]
# ## 0. 설치 패키지
#
# 이 실습은 LangGraph, OpenAI 모델, Tavily 검색 도구를 사용한다.
# 처음 실행하는 환경에서는 아래 명령으로 필요한 패키지를 설치한다.
#
# ```bash
# uv add langgraph langchain-openai langchain-tavily langchain-core python-dotenv grandalf
# ```
#
# `.env` 파일에는 다음 값을 설정한다.
#
# ```text
# OPENAI_API_KEY=발급받은_OpenAI_API_Key
# TAVILY_API_KEY=발급받은_Tavily_API_Key
# ```

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))

# 공통 환경 설정
# - .env 파일에서 API Key를 읽는다.
# - API Key가 없으면 실습 초반에 명확한 오류를 발생시킨다.
from const.const import API_KEY, MODEL, TAVILY_API_KEY

OPENAI_API_KEY = API_KEY
TAVILY_API_KEY = TAVILY_API_KEY

if not OPENAI_API_KEY:
    raise ValueError("OPENAI_API_KEY가 설정되어 있지 않다. ../.env 파일을 확인한다.")

if not TAVILY_API_KEY:
    raise ValueError("TAVILY_API_KEY가 설정되어 있지 않다. ../.env 파일을 확인한다.")

print("환경 변수 로드 완료")
# Out:
# 환경 변수 로드 완료

# %%
# LangGraph, LLM, Tavily 검색 도구를 불러온다.
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START, END
from langchain_tavily import TavilySearch
from langchain_nvidia_ai_endpoints import ChatNVIDIA
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from IPython.display import Image, display

# LLM은 검색 결과를 자연어 리포트로 정리할 때 사용한다.
llm = ChatNVIDIA(
    model=MODEL, api_key=API_KEY, temperature=0.2, timeout=600, max_tokens=2048
)

# TavilySearch는 외부 웹 검색을 수행하는 도구이다.
tavily_tool = TavilySearch(max_results=5)
# Out:
# /var/folders/cn/n1wp5rkx27j7415_2rb44sk00000gn/T/ipykernel_11976/2810130146.py:11: DeprecationWarning: The 'max_tokens' parameter is deprecated and will be removed in a future version. Please use 'max_completion_tokens' instead.
#   llm = ChatNVIDIA(

# %%
def normalize_tavily_results(raw_result) -> list[dict]:
    """Tavily 검색 결과를 list[dict] 형태로 정리한다.

    TavilySearch의 반환값은 보통 {"results": [...]} 형태이다.
    실습에서는 이후 노드가 사용하기 쉽도록 검색 결과 리스트만 추출한다.
    """
    if isinstance(raw_result, dict):
        return raw_result.get("results", [])

    if isinstance(raw_result, list):
        return raw_result

    return []


def format_search_results(results: list[dict]) -> str:
    """검색 결과를 LLM 프롬프트에 넣기 쉬운 문자열로 변환한다."""
    if not results:
        return "검색 결과가 없다."

    lines = []
    for idx, item in enumerate(results, start=1):
        title = item.get("title", "제목 없음")
        url = item.get("url", "URL 없음")
        content = item.get("content", "내용 없음")

        lines.append(f"[{idx}] {title}\nURL: {url}\n내용: {content}")

    return "\n\n".join(lines)


def show_graph(app):
    """그래프 구조를 시각화한다.

    Mermaid 이미지 생성이 실패하면 ASCII 그래프로 대체한다.
    """
    try:
        display(Image(app.get_graph().draw_mermaid_png()))
    except Exception as e:
        print(f"Mermaid 이미지 생성 실패: {e}")
        print(app.get_graph().draw_ascii())

# %% [markdown]
# ## 1. State 정의
#
# 2단계에서는 검색 결과를 바탕으로 최종 리포트를 생성한다.
# 따라서 `report` 필드를 추가한다.
#
# | 필드             | 의미                     |
# | ---------------- | ------------------------ |
# | `topic`          | 사용자가 알고 싶은 주제  |
# | `search_query`   | 실제 검색어              |
# | `search_results` | Tavily 검색 결과         |
# | `report`         | LLM이 작성한 최종 리포트 |

# %%
class ReportState(TypedDict):
    # 사용자가 입력한 원래 주제이다.
    topic: str

    # Tavily 검색에 사용한 검색어이다.
    search_query: str

    # Tavily에서 받은 검색 결과 목록이다.
    search_results: list[dict]

    # LLM이 작성한 뉴스 리포트이다.
    report: str

# %% [markdown]
# ## 2. 검색 노드 정의
#
# 1단계와 동일하게 Tavily 검색을 수행한다.
# 검색 노드는 `search_query`와 `search_results`를 반환한다.

# %%
def search_node(state: ReportState) -> dict:
    """Tavily 검색을 수행하는 노드이다."""

    query = state["topic"]
    print(f"검색어: {query}")

    raw_result = tavily_tool.invoke({"query": query})
    results = normalize_tavily_results(raw_result)

    print(f"검색 결과 수: {len(results)}")

    return {
        "search_query": query,
        "search_results": results,
    }

# %% [markdown]
# ## 3. 리포트 작성 체인 정의
#
# LLM은 검색 결과 리스트를 직접 이해하기 어렵다.
# 따라서 `format_search_results()` 함수로 검색 결과를 문자열로 바꾼 뒤 프롬프트에 넣는다.
#
# 날짜, 수치, 기관명은 검색 결과에 있는 경우에만 사용한다.
# 제공되지 않은 정보는 추정하지 않는다.

# %%
report_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """
너는 검색 결과를 바탕으로 짧은 뉴스 브리핑을 작성하는 AI이다.

작성 규칙:
1. 검색 결과에 있는 내용만 사용한다.
2. 날짜, 수치, 기관명은 원문에 있을 때만 사용한다.
3. 제공되지 않은 정보는 추정하지 않는다.
4. 한국어로 작성한다.
5. 제목, 핵심 요약, 주요 내용, 참고 링크 순서로 정리한다.
""".strip(),
        ),
        (
            "human",
            """
주제: {topic}

검색 결과:
{search_results}

위 검색 결과를 바탕으로 초보자도 이해할 수 있는 뉴스 리포트를 작성하라.
""".strip(),
        ),
    ]
)

# 프롬프트 → LLM → 문자열 출력 파서 순서로 실행되는 LangChain 체인이다.
report_chain = report_prompt | llm | StrOutputParser()

# %% [markdown]
# ## 4. 리포트 작성 노드 정의
#
# 이 노드는 검색 결과를 받아 LLM 리포트를 생성한다.
#
# 입력으로 사용하는 State 값은 다음과 같다.
#
# - `topic`
# - `search_results`
#
# 반환하는 State 값은 다음과 같다.
#
# - `report`

# %%
def report_node(state: ReportState) -> dict:
    """검색 결과를 바탕으로 뉴스 리포트를 작성하는 노드이다."""

    # 검색 결과를 프롬프트에 넣기 좋은 문자열로 변환한다.
    search_text = format_search_results(state["search_results"])

    # LLM 체인을 실행해 리포트를 생성한다.
    report = report_chain.invoke(
        {
            "topic": state["topic"],
            "search_results": search_text,
        }
    )

    return {"report": report}

# %% [markdown]
# ## 5. 그래프 구성
#
# 검색 노드 다음에 리포트 작성 노드를 연결한다.
#
# ```text
# START → 검색 → 리포트작성 → END
# ```

# %%
builder = StateGraph(ReportState)

# 두 개의 노드를 등록한다.
builder.add_node("검색", search_node)
builder.add_node("리포트작성", report_node)

# 순차 실행 흐름을 정의한다.
builder.add_edge(START, "검색")
builder.add_edge("검색", "리포트작성")
builder.add_edge("리포트작성", END)

app = builder.compile()

show_graph(app)

# %% [markdown]
# ## 6. 그래프 실행
#
# 최종 결과에서 `report` 값을 확인한다.

# %%
result = app.invoke(
    {
        "topic": "인공지능 최신 동향",
        "search_query": "",
        "search_results": [],
        "report": "",
    }
)

print(result["report"])
# Out:
# 검색어: 인공지능 최신 동향
# 검색 결과 수: 5
# **제목: 2025~2026년 인공지능(AI) 최신 동향: 에이전틱 AI·도메인 특화·거버넌스 중심으로 재편**
#
# ---
#
# **핵심 요약**
# 생성형 AI 등장 이후 시장이 급성장(2023년 2,146억 달러 → 2030년 1조 3,391억 달러 전망)하는 가운데, 2025~2026년은 **‘도입’을 넘어 ‘핵심 인프라·실무 적용’ 단계로 진입**하는 해로 평가된다. 주요 키워드는 **에이전틱 AI(Agentic AI), 도메인 특화 모델, AI 거버넌스·안전성, 피지컬 AI**이며, 기업 업무 구조가 ‘사람·에이전트·시스템 혼합’으로 바뀌고 AI 활용 역량이 채용 필수 스킬로 자리잡고 있다.
#
# ---
#
# **주요 내용**
#
# **1. 시장 규모 및 성장 전망**
# - 전 세계 AI 시장 규모는 2023년 기준 **2,146억 달러**이며, 2030년까지 **연평균 35.7% 성장해 1조 3,391억 달러**에 달할 전망(ETRI, 가트너 인용) [1].
# - 생성형 AI 시장은 2026년 **833억 달러**, 연 31.6% 성장 예상(캐럿글로벌/링커리어 인용) [2].
#
# **2. 2025~2026년 4대 핵심 기술 트렌드**
# | 트렌드 | 설명 | 주요 출처 |
# |---|---|---|
# | **에이전틱 AI (Agentic AI)** | 단순 챗봇을 넘어 목표를 위임받아 다단계 업무를 자율 수행하는 ‘AI 에이전트’가 개념 단계에서 실적용 단계로 전환. 가트너·맥킨지·IBM·포레스터가 1순위 트렌드로 꼽음. | [1], [3] |
# | **도메인 특화 모델** | 범용 LLM에서 특정 산업·업무에 최적화된 소형·특화 모델로 이동. ‘측정 가능한 신뢰성’ 확보가 핵심. | [2] |
# | **AI 거버넌스·안전성** | 가트너 ‘AI 거버넌스 플랫폼’ 선정. 미국(NIST AI안전연구소), EU(AI Act 세계 최초 제정), 영국·일본(안전연구소 설립) 등 글로벌 규제·안전 체계 본격 가동. | [1], [3] |
# | **피지컬 AI / 로보틱스 연계** | 디지털을 넘어 물리 세계와 상호작용하는 AI(로봇, 자율주행 등)로 확장. | [2] |
#
# **3. 기업·조직의 변화: ‘실험에서 핵심 인프라로’**
# - **업무 구조 변화**: 반응형·범용·불확실성 → **선제적(목표 위임형)·도메인 특화·측정 가능 신뢰성**으로 전환. 사람·에이전트·시스템이 혼합된 새로운 업무 구조 확산 [2].
# - **역량 요구사항 변화**: 코드 작성 능력보다 **‘에이전트에게 위임할 업무를 설계·분해하는 능력’**이 핵심 직무 역량으로 부상. 2026년 채용 시장에서 AI 활용 능력은 ‘기본 스킬’로 정착 [2].
#
# **4. 글로벌 정책·규제 동향 (2023~2025)**
# - **미국**: 국가 AI R&D 전략 업데이트(’23.5), AI 행정명령(’23.10), NIST 산하 AI안전연구소 설치(’23.11) [1].
# - **EU**: 세계 최초 AI 규제 법안 **‘AI Act’ 제정(’24.5)** [1].
# - **영국**: AI 안전성 정상회의·블레츨리 선언, 세계 최초 AI 안전연구소 설립(’23.11) [1].
# - **일본**: 문부과학성 AI 신뢰성 예산 30억엔 배정(’23), 경산성 산하 AI 안전연구소 설립(’24.2) [1].
# - **프랑스**: AI 행동 정상회의 개최 예정(’25.2) [1].
#
# **5. 리스크 및 과제**
# - **감정적 애착 위험**: AI 동료·챗봇과의 일상적 상호작용 증가로 인간의 감정적 의존 및 윤리적 이슈 대두(IBM Think) [4].
# - **인프라 미비**: 많은 기업이 2024년 IT 인프라가 AI 확장에 미흡함을 인지, 2025년은 인프라 정비·책임 있는 확장의 해로 전환 [4].
#
# ---
#
# **참고 링크**
# 1. ETRI - 인공지능 분야 산업·기술 동향 및 이슈: https://ettrends.etri.re.kr/ettrends/212/0905212008/0905212008.html
# 2. 윈스펙 - 2026 산업 동향·핵심 기술(AI 트렌드): https://winspec.co.kr/community/lecture/131658287
# 3. Botpress - 2026년에 주목해야 할 10가지 인공지능 트렌드: https://botpress.com/ko/blog/top-artificial-intelligence-trends
# 4. IBM Think - 2025년 AI 트렌드: 지금까지의 흐름과 앞으로의 전망: https://www.ibm.com/kr-ko/think/insights/artificial-intelligence-trends
# 5. 플렉스팀 블로그 - 국내·외 추천 AI 허브 사이트 총정리: https://flex.team/blog/2025/11/17/ai-recommended-site

# %% [markdown]
# ## 7. stream으로 단계별 실행 확인
#
# `stream()`을 사용하면 검색 노드와 리포트 작성 노드가 각각 어떤 값을 반환하는지 확인할 수 있다.

# %%
for event in app.stream(
    {
        "topic": "생성형 AI 교육 트렌드, url 오픈 가능한 자료만 추출하기",
        "search_query": "",
        "search_results": [],
        "report": "",
    },
    stream_mode="updates",
):
    # print(event)
    # for update_data in event.values():
    #     print(update_data)
    for update_data in event.values():
        if "search_results" in update_data:
            for i, item in enumerate(update_data["search_results"], start=1):
                print(f"\n[{i}] {item.get('title')}")
                print(item.get("url"))
                print(item.get("content"))
# Out:
# 검색어: 생성형 AI 교육 트렌드, url 오픈 가능한 자료만 추출하기
# 검색 결과 수: 5
#
# [1] 교육 분야에서 생성형 AI를 활용하는 10가지 주요 사례 | 가이드
# https://www.hdwebsoft.com/ko/blog/top-10-use-cases-of-generative-ai-in-education
# 방대한 데이터 세트를 실시간으로 분석할 수 있는 능력을 갖춘 생성형 AI는 교육에 상당한 이점을 제공합니다. 예를 들어, 교육 기관은 이를 통해 학습 패턴을 효과적으로 파악할 수 있습니다. 또한, 학생 성과를 정확하게 평가하고 다양한 학생 요구에 맞춰 교육 전략을 동적으로 조정할 수 있습니다. 교육에 생성형 AI를 도입하면 운영을 최적화할 뿐만 아니라 혁신적인 교수법을 도입할 수 있습니다. 궁극적으로 AI를 통해 학습은 더욱 흥미롭고 효과적이게 됩니다.
#
# 교육 분야의 생성형 AI 시장은 빠르게 성장하고 있습니다. 최근 추산에 따르면 전 세계 교육 AI 시장 규모는 189억 2,400만 달러에 달합니다. 2025년에는 개인 맞춤형 학습 솔루션과 고급 교육 도구에 대한 수요가 증가할 것으로 예상됩니다. 이러한 급증세는 생성형 AI(GenAI)가 교육 제공 및 소비 방식을 재정의하며 보여주는 혁신적인 잠재력을 강조합니다.
#
# ## 교육 분야에서 생성형 AI의 이점 [...] GenAI(생성형 AI)는 텍스트, 이미지, 비디오, 심지어 소프트웨어 코드와 같은 콘텐츠를 생성할 수 있는 고급 머신러닝 모델을 의미합니다. 교육 분야에서 이 기술은 기존의 교육 및 학습 과정을 혁신할 수 있는 능력으로 주목받고 있습니다. 특히, 개별 학생의 요구에 맞춘 맞춤형 학습 경험을 개발하고 고품질 교육 자료를 생성하는 데 활용되고 있습니다. 또한, 교육자들이 행정 업무를 더욱 효율적으로 관리할 수 있도록 지원하여 전반적인 생산성과 효율성을 향상시킵니다. [...] ### 오래된 학습 자료 복원
#
# 또한, 교육 분야의 생성형 AI는 오래되었거나 손상된 교육 자료에 새로운 생명을 불어넣을 수 있는 잠재력을 가지고 있습니다. 오래된 교과서, 강의 노트, 연구 논문 등의 스캔본을 분석하여 AI는 역사 문서, 사진, 영화 등 오래되거나 품질이 낮은 학습 자료를 개선할 수 있습니다. 이러한 과정을 통해 귀중한 지식을 보존할 뿐만 아니라 디지털 플랫폼을 통해 더 많은 사람들이 접근할 수 있도록 합니다.
#
# 더 나아가, 이러한 현대화는 가독성, 분석력, 이해도를 향상시켜 학생들이 콘텐츠에 더욱 깊이 몰입할 수 있도록 합니다. 궁극적으로 이는 학습 경험과 성과 향상으로 이어집니다.
#
# ### 온라인 튜터링
#
# AI 기반 온라인 튜터는 학생들에게 맞춤형 맞춤형 학습 지원을 제공함으로써 보충 교육 방식을 혁신하고 있습니다. 이러한 튜터는 일대일 상호작용을 시뮬레이션하여 특정 질문에 답변하고 복잡한 개념을 실시간으로 설명할 수 있습니다.
#
# [2] [Generative AI Training] Master AI for Work: The Essentials
# https://www.youtube.com/watch?v=jPBevYJ-6pI
# 📚 본 강의 소개
# 이 강의 영상은 GSC의 "3시간으로 평생 써먹는 생성형 AI+바이브 코딩 업무 자동화" 교육과정입니다.
# 비개발자도 쉽게 따라할 수 있는 실무 중심 AI 활용법을 배울 수 있습니다.
#
# 📢 아래 링크에서 교안과 학습자료를 다운받아 학습해보세요.
# 👉
#
# 💬 궁금한 점이 있으시면 댓글로 남겨주세요!
# 구독과 좋아요는 더 좋은 콘텐츠 제작에 큰 힘이 됩니다. 🙏
#
# #생성형AI #생성형AI교육 #ChatGPT #AI교육 #멀티모달AI #AI원리 #딥러닝 #GPT #인공지능 #AI트렌드 #Gemini #Claude #DeepSeek #AI업무활용 #프롬프트엔지니어링 #바이브코딩 #GSC #글로벌소프트웨어캠퍼스 [...] ✅ 이 영상을 보면 알 수 있는 것들
# - ChatGPT는 어떻게 당신의 질문을 이해할까? (텍스트 임베딩의 비밀)
# - 1,750억 개 매개변수의 정체와 AI 성능의 핵심 요소
# - GPT-1부터 ChatGPT까지, 4년간의 폭발적 진화 과정
# - LLM vs SLM, 당신에게 맞는 AI 모델은?
# - 2025년 AI 트렌드: ChatGPT, Gemini, Claude 누가 1등?
# - 텍스트+이미지+영상을 동시에 처리하는 멀티모달 AI의 작동 원리
#
# 💡 AI 도구를 그냥 쓰는 사람과 원리를 아는 사람의 차이
# 단순히 프롬프트만 입력하는 것을 넘어, AI의 작동 원리를 이해하면
# 더 정확하고 효율적으로 AI를 활용할 수 있습니다.
#
# 📌 이런 분들께 추천합니다
# ✔️ AI를 업무에 활용하고 싶은 직장인
# ✔️ ChatGPT 너머의 AI 생태계가 궁금한 분
# ✔️ 생성형 AI의 기술 원리를 쉽게 배우고 싶은 분
# ✔️ AI 트렌드를 놓치고 싶지 않은 모든 분 [...] 안 돼 있으면 AI 기능을 사용할 수 없는 모델들도 있지만 뭐 예를 들어 갤럭시 시리즈에서 라이브 트랜스레이터 기능 같은 거 써 보면 모바일 데이터나 와이파이를 끄고도 실시간으로 번역이 되거든요. 이것을 온디바이스 AI라고 하죠. 온디바이스 AI라는 것은 결국 디바이스 안에서 인공지능 기술이 구동되게 하는 건데 이게 되려면 매개 분수가 커서는 절대 안 되겠죠. 그래서 매개 분수를 낮추더라도 AI 기능이 유지되게 하는 기술이 발전하면 할수록 어 디바이스 안에서 인공지능이 돌아갈 수 있게 된다라는 거죠. 어, 이것은 추후에 다시 한번 말씀드리겠지만 여러분들 회사에서 만약에 폐쇄 환경이라든지 보안이 걸려 있는 엑셀이라든지 이런 것들을 컨트롤할 때는 사실 생성형의 기술을 쓸 수가 없었었거든요. 과거만 하더라도. 최근은 여러분들이 마음만 먹으면 충분히 가능해지는 것도 바로이 온디바이스 AI 때문입니다. 인바디드 AI라고 하면 이제 로봇 기술이랑 이제 온디바이스 AI가 합쳐지는 형태를 보통
#
# [3] AI 교육 — R&BD Partners
# https://rnbdp.com/ai-education
# 구글 코랩에서 설치하고 CustomVoice부터 보이스 클로닝까지. TTS 실습 교재.
#
# 자세히 보기) AI를 활용한 감사 업무
#
# Gemini로 법인카드 부정사용·계약 규정 위반·사규 위반 탐지. 감사 실무 특화 교재.
#
# 자세히 보기) OpenClaw 실전 운영 교재
#
# 맥미니 자동화 서버 세팅, OpenClaw 설치, Telegram 원격 제어, 개발 자동화 전체 과정.
#
# 자세히 보기 셋팅 및 개발 자동화 과정 (7h))
#
# AI TOOLS DIRECTORY
#
# ## AI 도구들
#
# 강의와 실무에서 직접 사용하는 AI 사이트 모음 — 카테고리별 핵심 도구
#
# LLM5개
#
# ChatGPT — OpenAI 생성형 AI 챗봇 로고
#
# ChatGPT
#
# A conversational AI system. 오픈AI의 대표 LLM. 실무 활용 1위.
#
# chatgpt.com바로가기 Claude — Anthropic 생성형 AI 챗봇 로고
#
# Claude (앤트로픽) [...] Claude (앤트로픽)
#
# 긴 문서 분석에 탁월. 코딩·글쓰기·분석 모두 강함.
#
# claude.ai바로가기 Microsoft Copilot — 통합 AI 어시스턴트 로고
#
# Microsoft Copilot
#
# 오피스 연동에 최적화. Word·Excel·Teams와 통합.
#
# copilot.microsoft.com바로가기 Google Gemini — 생성형 AI 챗봇 로고
#
# Gemini (구글)
#
# 구글 검색·드라이브와 연동. 멀티모달·코드 분석 강점.
#
# gemini.google.com바로가기 Perplexity — AI 답변형 검색엔진 로고
#
# Perplexity AI
#
# 출처 인용 검색에 강함. 실시간 웹 정보 기반 답변.
#
# perplexity.ai바로가기
#
# 마크다운 편집기5개
#
# 마크다운 에디터 — R&BD Partners 자체 개발 SaaS 썸네일
#
# 마크다운 편집기 한국GPT협회
#
# 실시간 미리보기 지원 마크다운 에디터. 강의에서 활용. [...] gamma.app바로가기 미리캔버스 — 한국어 디자인 도구 썸네일
#
# 미리캔버스
#
# 3분 만에 발표자료·SNS 디자인 완성. 한국형 캔바.
#
# miricanvas.com바로가기 Canva — 온라인 디자인 플랫폼 썸네일
#
# Canva
#
# 소셜미디어·발표·포스터·영상·로고 등 올인원 디자인 툴.
#
# canva.com바로가기 Genspark — AI 검색 에이전트 로고
#
# 젠스파크 (Genspark)
#
# 검색부터 슬라이드·스파크페이지까지 자동으로 만들어주는 올인원 AI.
#
# genspark.ai바로가기
#
# 음악1개
#
# Suno — AI 음악 생성 도구 썸네일
#
# Suno
#
# 텍스트 프롬프트 하나로 완성된 음악 생성. 누구나 작곡 가능.
#
# suno.com바로가기
#
# 이미지2개
#
# Midjourney — AI 이미지 생성 도구 썸네일
#
# Midjourney
#
# AI 이미지 생성 최강자. 프롬프트로 고품질 이미지 생성.
#
# midjourney.com바로가기 Google AI Studio — Gemini 개발 환경 로고
#
# [4] 교육자를 위한 생성형 AI - Google for Education
# https://edu.exceedlms.com/student/path/1722724-ai
# 이 섹션에서는 AI의 핵심 개념을 살펴보겠습니다. 교육 분야 AI를 책임감 있게 사용하기 위한 전략에 초점을 맞추어 진행되며, 교실에서 윤리적이고 적절한 방식으로 AI를 탐색하는 방법을 알아봅니다. 또한 AI 출력을 효과적으로 평가하는 방법을 배우며 사고력을 기를 수 있습니다.
#
#  ### 일상 환경에서 AI 이해하기
#  ### 생성형 AI 및 AI 도구 살펴보기
#  ### 책임감 있는 AI 사용을 위한 노력
#
# 이 섹션은 AI를 계속해서 탐색해 나가기 위한 발판이 될 것입니다. 이 섹션에서는 기본 개념을 요약하고 책임감 있는 AI 사용과 효과적인 프롬프트 작성법에 대한 핵심 내용을 돌아봅니다. 또한 교육 분야 AI에 대해 지속적으로 학습할 수 있도록 선별된 리소스 목록이 제공됩니다.
#
#  ### 학습한 내용 복습 및 유용한 리소스 액세스
#
# 최종 평가를 치르면 수료 인증서를 취득할 수 있습니다(선택사항).
#
#  ### 평가(선택사항)
#
# 지원 리소스를 둘러보세요.
#
#  ### 리소스 [...] Get Started
#
# 이 과정에서는 텍스트, 이미지, 기타 미디어 등 새로운 콘텐츠를 생성하는 AI인 생성형 AI를 알아봅니다. 생성형 AI 도구를 활용해 일상적인 업무에 드는 시간을 절약하고, 학생의 요구에 교육을 맞춤설정하고, 수업과 활동을 창의적인 방식으로 개선함으로써 교수법을 지원하는 방법을 살펴봅니다. Gemini와 ChatGPT는 대화 프롬프트와 함께 사용되는 생성형 AI의 대표적인 예입니다. 즉, 사용자가 무언가를 요청하면 AI 도구가 응답하는 방식입니다. 이 과정을 통해 AI 도구를 다루는 검증된 전략을 배우고 수업 계획 및 업데이트, 교육 자료 준비, 보이지 않는 행정 업무 관리 등 다양한 작업에 AI 도구를 활용하는 방법을 연습할 수 있습니다.
#
# ## By the end of this course, you will be able to:
#
# [5] 4차산업시대의생성형AI활용가이드.pdf
# https://ecampus.pro.ac.kr/pluginfile.php/39/mod_ubboard/attachment/59496/4%EC%B0%A8%EC%82%B0%EC%97%85%EC%8B%9C%EB%8C%80%EC%9D%98%EC%83%9D%EC%84%B1%ED%98%95AI%ED%99%9C%EC%9A%A9%EA%B0%80%EC%9D%B4%EB%93%9C.pdf?forcedownload=1
# 4 I. 생성형 AI 소개 18 04. 유사 서비스 기 업 명 칭 주요 특징 보유 초거대 AI 챗GPT 대화형 AI 챗봇, 친화적 상호작용을 통해 질문을 이해하고, 필요로하는 정보 제공 GPT 3.5 바드 향후 수 주 내 출시 예정. 챗GPT와 비슷한 기능이나 챗GPT와 달리 최근에 일어난 일에 대해서도 답변 가능 람다 어니봇 챗GPT와 유사한 AI 챗봇 3월 출시 예정. 독립형 애플리케이션 출시 후 기 존 검색 엔진과 통합 예 어니 서치GPT 생성형 AI. 상반기 출시 예정. 요약 정보가 필요한 검색은 다양한 콘텐츠를 활용한 답변 제시 하이퍼클로바 오픈AI 미국 구글 미국 바이두 중국 네이버 한국 < 국내외 생성형 AI 주요 개발 현황 > 3)  마이크로소프트 빙 | 위키백과, 우리 모두의 백과사전 4)  마이크로소프트, AI 기반 빙·엣지 공개…검색 새 패러다임 연다 | Microsoft 2023년 2월 7일, 마이크로소프트에서 “the new Bing”으로 광고되는 챗봇

# %% [markdown]
# ## 정리
#
# 이 단계에서 확인한 내용은 다음과 같다.
#
# 1. 하나의 그래프 안에서 외부 검색과 LLM 생성을 순차적으로 연결할 수 있다.
# 2. 검색 결과는 LLM이 이해할 수 있도록 문자열로 정리해야 한다.
# 3. LangGraph의 각 노드는 자신이 담당하는 작업만 수행하고, 변경할 State 값만 반환한다.
# 4. 다음 단계에서는 검색 결과가 부족할 때 다시 검색하는 조건부 흐름을 추가한다.

# %% [markdown]
# ---
#
# ## 핵심 정리
#
# ```python
# # 1. Tavily Search 도구 초기화
# from langchain_tavily import TavilySearch
#
# tavily_tool = TavilySearch(max_results=5)
#
# raw_result = tavily_tool.invoke({"query": "검색어"})
# results = raw_result["results"]
#
#
# # 2. 검색 결과를 LLM 입력용 문자열로 변환
# def format_search_results(results: list[dict]) -> str:
#     if not results:
#         return "검색 결과가 없다."
#
#     lines = []
#
#     for idx, item in enumerate(results, start=1):
#         title = item.get("title", "제목 없음")
#         url = item.get("url", "URL 없음")
#         content = item.get("content", "내용 없음")
#
#         lines.append(
#             f"[{idx}] {title}\n"
#             f"URL: {url}\n"
#             f"내용: {content}"
#         )
#
#     return "\n\n".join(lines)
#
#
# # 3. State 정의
# from typing_extensions import TypedDict
#
# class ReportState(TypedDict):
#     topic: str
#     search_query: str
#     search_results: list[dict]
#     report: str
#
#
# # 4. 검색 노드
# def search_node(state: ReportState) -> dict:
#     query = state["topic"]
#
#     raw_result = tavily_tool.invoke({"query": query})
#     results = raw_result["results"]
#
#     return {
#         "search_query": query,
#         "search_results": results,
#     }
#
#
# # 5. 리포트 작성 노드
# def report_node(state: ReportState) -> dict:
#     search_text = format_search_results(state["search_results"])
#
#     report = report_chain.invoke({
#         "topic": state["topic"],
#         "search_results": search_text,
#     })
#
#     return {"report": report}
#
#
# # 6. 그래프 구성
# from langgraph.graph import StateGraph, START, END
#
# builder = StateGraph(ReportState)
#
# builder.add_node("검색", search_node)
# builder.add_node("리포트작성", report_node)
#
# builder.add_edge(START, "검색")
# builder.add_edge("검색", "리포트작성")
# builder.add_edge("리포트작성", END)
#
# app = builder.compile()
# ```
#
# - 노드 설명
#
# | 노드       | 역할                                                                            |
# | ---------- | ------------------------------------------------------------------------------- |
# | 검색       | 사용자의 주제를 검색어로 사용해 Tavily Search API로 웹 검색을 수행한다.         |
# | 리포트작성 | 검색 결과를 LLM 프롬프트에 넣기 좋은 문자열로 변환한 뒤 뉴스 리포트를 생성한다. |
#
# - State 필드 설명
#
# | State 필드       | 의미                                               |
# | ---------------- | -------------------------------------------------- |
# | `topic`          | 사용자가 알고 싶은 원래 주제이다.                  |
# | `search_query`   | 실제 Tavily 검색에 사용한 검색어이다.              |
# | `search_results` | Tavily에서 반환한 검색 결과 목록이다.              |
# | `report`         | LLM이 검색 결과를 바탕으로 작성한 최종 리포트이다. |
#
# 이 실습은 LangGraph에서 **외부 검색 API 호출 결과를 LLM 생성 노드로 전달하는 기본 파이프라인** 예제이다.
#
# 핵심 흐름은 다음과 같다.
#
# ```text
# START
#   ↓
# 검색
#   ↓
# 리포트작성
#   ↓
# END
# ```
#
# 즉, 07-1이 “검색 도구를 노드로 연결하는 실습”이라면, 07-2는 여기에 **LLM 후처리 노드**를 추가해 검색 결과를 사람이 읽기 쉬운 리포트로 변환하는 실습이다.
